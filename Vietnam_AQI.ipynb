# %% [raw]
# Project Title: Air Quality Analysis in Vietnam for 2024: A Visualization Project with Matplotlib.
#
# Project Description:
# This project provides an exploratory analysis of air quality trends in Vietnam for the year 2024, using AQI data. Focusing specifically on periods of heightened air pollution, such as October and November, this project seeks to uncover patterns and possible causes of seasonal pollution spikes. With data visualization facilitated by Matplotlib, the project highlights daily AQI changes, emphasizing key pollutants that impact urban and rural areas.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# load AQI dataset (read_csv)
AQI_data = pd.read_csv("C:/Users/User/Downloads/data_AQI.csv")
AQI_data
# Out:
#              Date                   Country                          Status  \
# 0      2022-07-21                   Albania                            Good
# 1      2022-07-21                   Algeria                        Moderate
# 2      2022-07-21                   Andorra                        Moderate
# 3      2022-07-21                    Angola  Unhealthy for Sensitive Groups
# 4      2022-07-21                 Argentina                        Moderate
# ...           ...                       ...                             ...
# 15926  2024-10-31  United States of America  Unhealthy for Sensitive Groups
# 15927  2024-10-31                Uzbekistan                       Unhealthy
# 15928  2024-10-31                   Vatican                        Moderate
# 15929  2024-10-31                 Venezuela                            Good
# 15930  2024-10-31                   Vietnam                        Moderate
#
#        AQI Value
# 0             14
# 1             65
# ...

# %%
# Convert to DateTime

AQI_data['Date'] = pd.to_datetime(AQI_data['Date'])
AQI_data['Date']
# Out:
# 0       2022-07-21
# 1       2022-07-21
# 2       2022-07-21
# 3       2022-07-21
# 4       2022-07-21
#            ...
# 15926   2024-10-31
# 15927   2024-10-31
# 15928   2024-10-31
# 15929   2024-10-31
# 15930   2024-10-31
# Name: Date, Length: 15931, dtype: datetime64[ns]

# %%
# Filter data for a specific country

vietnam_2024 = AQI_data[(AQI_data['Country'] == 'Vietnam') & (AQI_data['Date'].dt.year == 2024)]
vietnam_2024
# Out:
#             Date  Country                          Status  AQI Value
# 13117 2024-06-06  Vietnam                        Moderate         63
# 13250 2024-06-06  Vietnam                        Moderate         63
# 13383 2024-06-13  Vietnam                        Moderate         52
# 13514 2024-06-20  Vietnam                        Moderate         59
# 13645 2024-06-27  Vietnam                        Moderate         67
# 13775 2024-07-04  Vietnam                            Good         50
# 13903 2024-07-11  Vietnam                        Moderate         57
# 14032 2024-07-18  Vietnam                            Good         32
# 14162 2024-07-25  Vietnam                        Moderate         55
# 14291 2024-08-01  Vietnam                            Good         38
# 14421 2024-08-08  Vietnam                            Good         47
# 14551 2024-08-15  Vietnam                            Good         49
# 14680 2024-08-22  Vietnam                        Moderate         71
# ...

# %%
# Line plot for AQI over time

plt.figure(figsize=( 10, 6))
plt.plot(vietnam_2024['Date'],vietnam_2024['AQI Value'], color = 'blue', label = 'Vietnam AQI')
plt.title('AQI Trend Over Time for Vietnam')
plt.xlabel('Date')
plt.ylabel('Air Quality Index(AQI)')
plt.legend()
plt.grid(True)

plt.show()
